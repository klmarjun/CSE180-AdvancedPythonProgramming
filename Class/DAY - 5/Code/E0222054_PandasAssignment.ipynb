# %%
import pandas as pd

# %%
sample_df = pd.read_excel("D:\SRET\FirstYear\TERM3\AdvancedPython\Class\DAY - 5\Data\Players.xlsx")

# %%
sample_df
# Out:
#         Player_Name        DOB Batting_Hand           Bowling_Skill   Country
# 0    A Ashish Reddy 1991-02-24   Right_Hand        Right-arm medium     India
# 1        A Chandila 1983-12-05   Right_Hand      Right-arm offbreak     India
# 2          A Chopra 1977-09-19   Right_Hand      Right-arm offbreak     India
# 3       A Choudhary        NaT   Right_hand    Left-arm fast-medium       NaN
# 4       A Dananjaya        NaT   Right_Hand      Right-arm offbreak       NaN
# ..              ...        ...          ...                     ...       ...
# 561     Younis Khan 1977-11-29   Right_Hand        Right-arm medium  Pakistan
# 562       YS Chahal 1990-07-23   Right_Hand         Legbreak googly     India
# 563    Yuvraj Singh 1981-12-12    Left_Hand  Slow left-arm orthodox     India
# 564     YV Takawale 1984-11-05   Right_Hand                     NaN     India
# 565          Z Khan 1978-10-07   Right_Hand    Left-arm fast-medium     India
#
# [566 rows x 5 columns]

# %% [markdown]
# ### Question1: Count the total number of right hand batsman

# %%
con = sample_df['Batting_Hand']=="Right_Hand"

# %%
sample_df[con]
# Out:
#         Player_Name        DOB Batting_Hand          Bowling_Skill   Country
# 0    A Ashish Reddy 1991-02-24   Right_Hand       Right-arm medium     India
# 1        A Chandila 1983-12-05   Right_Hand     Right-arm offbreak     India
# 2          A Chopra 1977-09-19   Right_Hand     Right-arm offbreak     India
# 4       A Dananjaya        NaT   Right_Hand     Right-arm offbreak       NaN
# 5        A Flintoff 1977-12-06   Right_Hand  Right-arm fast-medium   England
# ..              ...        ...          ...                    ...       ...
# 560       YK Pathan 1982-11-17   Right_Hand     Right-arm offbreak     India
# 561     Younis Khan 1977-11-29   Right_Hand       Right-arm medium  Pakistan
# 562       YS Chahal 1990-07-23   Right_Hand        Legbreak googly     India
# 564     YV Takawale 1984-11-05   Right_Hand                    NaN     India
# 565          Z Khan 1978-10-07   Right_Hand   Left-arm fast-medium     India
#
# [373 rows x 5 columns]

# %% [markdown]
# ### Question2: Extract all player names from India

# %%
con = sample_df['Country']=="India"

# %%
sample_df[con]
# Out:
#         Player_Name        DOB Batting_Hand           Bowling_Skill Country
# 0    A Ashish Reddy 1991-02-24   Right_Hand        Right-arm medium   India
# 1        A Chandila 1983-12-05   Right_Hand      Right-arm offbreak   India
# 2          A Chopra 1977-09-19   Right_Hand      Right-arm offbreak   India
# 8          A Kumble 1970-10-17   Right_Hand         Legbreak googly   India
# 9          A Mishra 1982-11-24   Right_Hand                Legbreak   India
# ..              ...        ...          ...                     ...     ...
# 560       YK Pathan 1982-11-17   Right_Hand      Right-arm offbreak   India
# 562       YS Chahal 1990-07-23   Right_Hand         Legbreak googly   India
# 563    Yuvraj Singh 1981-12-12    Left_Hand  Slow left-arm orthodox   India
# 564     YV Takawale 1984-11-05   Right_Hand                     NaN   India
# 565          Z Khan 1978-10-07   Right_Hand    Left-arm fast-medium   India
#
# [264 rows x 5 columns]

# %% [markdown]
# ### Question3:  How many players are there from south africa?

# %%
con = sample_df['Country']=='South Africa'

# %%
sample_df[con]
# Out:
#           Player_Name        DOB Batting_Hand           Bowling_Skill  \
# 13              A Nel 1977-07-15   Right_Hand   Right-arm fast-medium
# 27     AB de Villiers 1984-02-17   Right_Hand        Right-arm medium
# 85       BE Hendricks 1990-06-08    Left_Hand    Left-arm fast-medium
# 99          CA Ingram 1985-07-03    Left_Hand                Legbreak
# 103         CH Morris 1987-04-30   Right_Hand   Right-arm fast-medium
# 115        D du Preez 1981-11-08   Right_Hand   Right-arm fast-medium
# 120           D Wiese 1985-05-18   Right_Hand   Right-arm medium-fast
# 122         DA Miller 1989-06-10    Left_Hand      Right-arm offbreak
# 133         DJ Jacobs 1982-11-04   Right_Hand        Right-arm medium
# 150          DW Steyn 1983-06-27   Right_Hand          Right-arm fast
# 154       F Behardien 1983-10-09   Right_Hand   Right-arm fast-medium
# 155      F du Plessis 1984-07-13   Right_Hand                Legbreak
# ...

# %% [markdown]
# ### Question4: List out the names of the players from India and England who are left hand batsman and right arm fast bowler

# %%
con1 = sample_df['Country']=='India'

# %%
con2 = sample_df['Country']=='England'

# %%
sample_df1 = sample_df[con1 | con2]

# %%
sample_df1
# Out:
#         Player_Name        DOB Batting_Hand           Bowling_Skill  Country
# 0    A Ashish Reddy 1991-02-24   Right_Hand        Right-arm medium    India
# 1        A Chandila 1983-12-05   Right_Hand      Right-arm offbreak    India
# 2          A Chopra 1977-09-19   Right_Hand      Right-arm offbreak    India
# 5        A Flintoff 1977-12-06   Right_Hand   Right-arm fast-medium  England
# 8          A Kumble 1970-10-17   Right_Hand         Legbreak googly    India
# ..              ...        ...          ...                     ...      ...
# 560       YK Pathan 1982-11-17   Right_Hand      Right-arm offbreak    India
# 562       YS Chahal 1990-07-23   Right_Hand         Legbreak googly    India
# 563    Yuvraj Singh 1981-12-12    Left_Hand  Slow left-arm orthodox    India
# 564     YV Takawale 1984-11-05   Right_Hand                     NaN    India
# 565          Z Khan 1978-10-07   Right_Hand    Left-arm fast-medium    India
#
# [278 rows x 5 columns]

# %%
con3 = sample_df1['Batting_Hand']=='Left_Hand'

# %%
sample_df2 = sample_df1[con3]

# %%
sample_df2
# Out:
#          Player_Name        DOB Batting_Hand           Bowling_Skill  Country
# 26         AB Barath 1990-04-14    Left_Hand      Right-arm offbreak    India
# 40        AG Murtaza 1990-01-01    Left_Hand  Slow left-arm orthodox    India
# 44        AL Menaria 1990-10-29    Left_Hand  Slow left-arm orthodox    India
# 45          AM Nayar 1983-10-08    Left_Hand        Right-arm medium    India
# 51     Anirudh Singh 1980-08-02    Left_Hand        Right-arm medium    India
# 52      Ankit Sharma 1991-04-20    Left_Hand  Slow left-arm orthodox    India
# 59          AR Patel 1994-01-20    Left_Hand  Slow left-arm orthodox    India
# 77          BA Bhatt 1990-05-13    Left_Hand  Slow left-arm orthodox    India
# 83           BB Sran 1992-12-10    Left_Hand         Left-arm medium    India
# 86      Bipul Sharma 1983-09-28    Left_Hand  Slow left-arm orthodox    India
# 128        DH Yagnik 1983-06-22    Left_Hand                     NaN    India
# ...

# %%
con4 = sample_df2['Bowling_Skill']=='Right-arm fast'

# %%
sample_df3 = sample_df2[con4]

# %%
sample_df3
# Out:
#       Player_Name        DOB Batting_Hand   Bowling_Skill Country
# 526  TP Sudhindra 1984-04-24    Left_Hand  Right-arm fast   India

# %% [markdown]
# ### Question5: Get the list of players who are left arm fast or right arm fast medium

# %%
con1 = sample_df['Bowling_Skill']=='left arm fast'

# %%
con2 = sample_df['Bowling_Skill']=='Right-arm fast-medium'

# %%
sample_df1 = sample_df[con1|con2]

# %%
sample_df1
# Out:
#      Player_Name        DOB Batting_Hand          Bowling_Skill       Country
# 5     A Flintoff 1977-12-06   Right_Hand  Right-arm fast-medium       England
# 13         A Nel 1977-07-15   Right_Hand  Right-arm fast-medium  South Africa
# 24     AA Noffke 1977-04-30   Right_Hand  Right-arm fast-medium     Australia
# 29   AB McDonald 1981-06-05   Right_Hand  Right-arm fast-medium     Australia
# 33     AC Thomas 1977-02-09   Right_Hand  Right-arm fast-medium       England
# ..           ...        ...          ...                    ...           ...
# 510     T Curran        NaT   Right_hand  Right-arm fast-medium           NaN
# 511  T Henderson 1974-08-01   Right_Hand  Right-arm fast-medium  South Africa
# 513     T Mishra 1986-12-22   Right_Hand  Right-arm fast-medium         India
# 532     Umar Gul 1984-04-14   Right_Hand  Right-arm fast-medium      Pakistan
# 534     UT Yadav 1987-10-25   Right_Hand  Right-arm fast-medium         India
#
# [68 rows x 5 columns]
